# %% [markdown]
# # Explanation

# %% [markdown]
# In this section, you’ll find a description of how extreme precipitation is defined here, how it can be measured, and strategies on adaptation measures to reduce the impact of extreme precipitation. The explanation begins with describing the concept of return periods, and how we apply it here. You’ll also learn how extreme precipitation risk is shaped by hazard, exposure, and vulnerability, and what practical adaptation options exist to address each of these dimensions. Together, these sections provide a structured foundation for understanding extreme precipitation under climate change and from early signals to long-term impacts — and what can be done to manage the associated risk.
#
# - [About return periods](./explanation/return_period.md)
# - [Extreme precipitation as a hazard](./explanation/hazard.md)
# - [Understanding exposure to extreme precipitation](./explanation/exposure.md)
# - [Understanding vulnerabilities to extreme precipitation](./explanation/vulnerability.md)
# - [Risk estimation](./explanation/risk.md)
# - [Adaptation to risk](./explanation/adaptation.md)
